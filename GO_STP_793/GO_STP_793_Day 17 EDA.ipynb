# %% [markdown]
# <b>EDA</b> - is cleaning of data or analysis of data
# -> use visualization methods
# -> helps us decide which features to use
# -> gives us insights to the data
#
# <b>Steps for EDA</b>
#
# 1. check description of data
# 2. cleaning - handling missing data, removing outliers
# 3. finding relationships between features

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Datasets\haberman.csv')

# %%
data
# Out:
#      age  year  nodes  status
# 0     30    64      1       1
# 1     30    62      3       1
# 2     30    65      0       1
# 3     31    59      2       1
# 4     31    65      4       1
# ..   ...   ...    ...     ...
# 300   74    63      0       1
# 301   75    62      1       1
# 302   76    67      0       1
# 303   77    65      3       1
# 304   78    65      1       2
#
# [305 rows x 4 columns]

# %%
data.shape
# Out:
# (305, 4)

# %%
data.columns
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
data['status'].value_counts()   #checking whether the data is balanced or not
# Out:
# 1    225
# 2     80
# Name: status, dtype: int64

# %%
data.count()
# Out:
# age       305
# year      305
# nodes     305
# status    305
# dtype: int64

# %%
#checking whether data contains any null values

sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.isnull().sum()   #summing up the returned values
# Out:
# age       0
# year      0
# nodes     0
# status    0
# dtype: int64

# %%
sns.set_style('whitegrid')

#visualizations of data['status'].value_counts()
sns.countplot(x = 'status', data = data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='count'>

# %%
data.describe()
# Out:
#               age        year       nodes      status
# count  305.000000  305.000000  305.000000  305.000000
# mean    52.357377   62.868852    4.032787    1.262295
# std     10.678010    3.242783    7.200528    0.440605
# min     30.000000   58.000000    0.000000    1.000000
# 25%     44.000000   60.000000    0.000000    1.000000
# 50%     52.000000   63.000000    1.000000    1.000000
# 75%     60.000000   66.000000    4.000000    2.000000
# max     78.000000   69.000000   52.000000    2.000000

# %% [markdown]
# # Bivariate Analysis

# %%
sns.set_style('whitegrid')

sns.FacetGrid(data, hue = 'status').map(plt.scatter, 'age', 'year').add_legend()

# %%
sns.set_style('whitegrid')

sns.FacetGrid(data, hue = 'status').map(plt.scatter, 'age', 'nodes').add_legend()

# %%
sns.set_style('darkgrid')
sns.pairplot(data, hue='status', vars=['age', 'year', 'nodes'], palette = 'gist_rainbow')

# %% [markdown]
# # Univariate

# %%
live = data.loc[data["status"] == 1]
dead = data.loc[data["status"] == 2]

plt.plot(live["age"], np.zeros_like(live['age']), 'o')
plt.plot(dead['age'], np.zeros_like(dead['age']), 'o')

plt.show()

# %%
sns.FacetGrid(data, hue = 'status').map(sns.distplot, "year").add_legend()
# Out:
# c:\users\harshit\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\harshit\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['age'], color='darkred')
# Out:
# c:\users\harshit\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.histplot(data['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.boxplot(x = 'status', y = 'age', data = data)
plt.show()

# %%
sns.boxplot(x = 'status', y = 'nodes', data = data)
plt.show()
#this shows that the people having less number of nodes are having 
#more chances to survive instead of those having more number of
#nodes.
